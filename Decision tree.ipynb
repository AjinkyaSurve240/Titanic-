# %%
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
import pyspark.sql.functions as F
from pyspark.sql.types import DoubleType, StringType, StructType, StructField
from pyspark.ml.feature import StringIndexer, VectorAssembler, QuantileDiscretizer
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark import SparkContext
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.linalg import Vectors, VectorUDT
import pandas as pd
import numpy as np
from sklearn import metrics 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName("Titanic data ").getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data = spark.read.csv("/FileStore/tables/Titanic1.csv", header="true", inferSchema="true")
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>last</th><th>first</th><th>gender</th><th>age</th><th>Pclass</th><th>fare</th><th>embarked</th><th>survived</th></tr></thead><tbody><tr><td>Braund</td><td>Mr. Owen Harris</td><td>M</td><td>22.0</td><td>3</td><td>7.25</td><td>Southampton</td><td>no</td></tr><tr><td>Cumings</td><td>Mrs. John Bradley (Florence Briggs Thayer)</td><td>F</td><td>38.0</td><td>1</td><td>71.2833</td><td>Cherbourg</td><td>yes</td></tr><tr><td>Heikkinen</td><td>Miss Laina</td><td>F</td><td>26.0</td><td>3</td><td>7.925</td><td>Southampton</td><td>yes</td></tr><tr><td>Futrelle</td><td>Mrs. Jacques Heath (Lily May Peel)</td><td>F</td><td>35.0</td><td>1</td><td>53.1</td><td>Southampton</td><td>yes</td></tr><tr><td>Allen</td><td>Mr. William Henry</td><td>M</td><td>35.0</td><td>3</td><td>8.05</td><td>Southampton</td><td>no</td></tr><tr><td>Moran</td><td>Mr. James</td><td>M</td><td>null</td><td>3</td><td>8.4583</td><td>Queenstown</td><td>no</td></tr><tr><td>McCarthy</td><td>Mr. Timothy J</td><td>M</td><td>54.0</td><td>1</td><td>51.8625</td><td>Southampton</td><td>no</td></tr><tr><td>Palsson</td><td>Master Gosta Leonard</td><td>M</td><td>2.0</td><td>3</td><td>21.075</td><td>Southampton</td><td>no</td></tr><tr><td>Johnson</td><td>Mrs. Oscar W (Elisabeth Vilhelmina Berg)</td><td>F</td><td>27.0</td><td>3</td><td>11.1333</td><td>Southampton</td><td>yes</td></tr><tr><td>Nasser</td><td>Mrs. Nicholas (Adele Achem)</td><td>F</td><td>14.0</td><td>2</td><td>30.0708</td><td>Cherbourg</td><td>yes</td></tr><tr><td>Sandstrom</td><td>Miss Marguerite Rut</td><td>F</td><td>4.0</td><td>3</td><td>16.7</td><td>Southampton</td><td>yes</td></tr><tr><td>Bonnell</td><td>Miss Elizabeth</td><td>F</td><td>58.0</td><td>1</td><td>26.55</td><td>Southampton</td><td>yes</td></tr><tr><td>Saundercock</td><td>Mr. William Henry</td><td>M</td><td>20.0</td><td>3</td><td>8.05</td><td>Southampton</td><td>no</td></tr><tr><td>Andersson</td><td>Mr. Anders Johan</td><td>M</td><td>39.0</td><td>3</td><td>31.275</td><td>Southampton</td><td>no</td></tr><tr><td>Vestrom</td><td>Miss Hulda Amanda Adolfina</td><td>F</td><td>14.0</td><td>3</td><td>7.8542</td><td>Southampton</td><td>no</td></tr><tr><td>Hewlett</td><td>Mrs. (Mary D Kingcome)</td><td>F</td><td>55.0</td><td>2</td><td>16.0</td><td>Southampton</td><td>yes</td></tr><tr><td>Rice</td><td>Master Eugene</td><td>M</td><td>2.0</td><td>3</td><td>29.125</td><td>Queenstown</td><td>no</td></tr><tr><td>Williams</td><td>Mr. Charles Eugene</td><td>M</td><td>null</td><td>2</td><td>13.0</td><td>Southampton</td><td>yes</td></tr><tr><td>Vander Planke</td><td>Mrs. Julius (Emelia Maria Vandemoortele)</td><td>F</td><td>31.0</td><td>3</td><td>18.0</td><td>Southampton</td><td>no</td></tr><tr><td>Masselmani</td><td>Mrs. Fatima</td><td>F</td><td>null</td><td>3</td><td>7.225</td><td>Cherbourg</td><td>yes</td></tr><tr><td>Fynney</td><td>Mr. Joseph J</td><td>M</td><td>35.0</td><td>2</td><td>26.0</td><td>Southampton</td><td>no</td></tr><tr><td>Beesley</td><td>Mr. Lawrence</td><td>M</td><td>34.0</td><td>2</td><td>13.0</td><td>Southampton</td><td>yes</td></tr><tr><td>McGowan</td><td>" Miss Anna ""Annie"""</td><td>F</td><td>15.0</td><td>3</td><td>8.0292</td><td>Queenstown</td><td>yes</td></tr><tr><td>Sloper</td><td>Mr. William Thompson</td><td>M</td><td>28.0</td><td>1</td><td>35.5</td><td>Southampton</td><td>yes</td></tr><tr><td>Palsson</td><td>Miss Torborg Danira</td><td>F</td><td>8.0</td><td>3</td><td>21.075</td><td>Southampton</td><td>no</td></tr><tr><td>Asplund</td><td>Mrs. Carl Oscar (Selma Augusta Emilia Johansson)</td><td>F</td><td>38.0</td><td>3</td><td>31.3875</td><td>Southampton</td><td>yes</td></tr><tr><td>Emir</td><td>Mr. Farred Chehab</td><td>M</td><td>null</td><td>3</td><td>7.225</td><td>Cherbourg</td><td>no</td></tr><tr><td>Fortune</td><td>Mr. Charles Alexander</td><td>M</td><td>19.0</td><td>1</td><td>263.0</td><td>Southampton</td><td>no</td></tr><tr><t ...

# %%
data.createOrReplaceTempView("data")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
empty_columns =[]
for col_name in data.columns:
    empty_values = data.where(F.col(col_name).isNull()).count()
    if(empty_values > 0):
        empty_columns.append((col_name, empty_values))
print(empty_columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[(&#39;age&#39;, 177)]
# </div>

# %%
round(spark.sql("SELECT AVG(age) FROM data").collect()[0][0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: 30</div>

# %%
data = data.fillna(30, subset=['age'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
labels = [StringIndexer(inputCol=column, outputCol=column+"_new").fit(data) for column in ["gender","embarked","survived"]]

pipeline = Pipeline(stages=labels)
data = pipeline.fit(data).transform(data)

data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+--------------------+------+----+------+-------+-----------+--------+----------+------------+------------+
#          last|               first|gender| age|Pclass|   fare|   embarked|survived|gender_new|embarked_new|survived_new|
# +-------------+--------------------+------+----+------+-------+-----------+--------+----------+------------+------------+
#        Braund|     Mr. Owen Harris|     M|22.0|     3|   7.25|Southampton|      no|       0.0|         0.0|         0.0|
#       Cumings|Mrs. John Bradley...|     F|38.0|     1|71.2833|  Cherbourg|     yes|       1.0|         1.0|         1.0|
#     Heikkinen|          Miss Laina|     F|26.0|     3|  7.925|Southampton|     yes|       1.0|         0.0|         1.0|
#      Futrelle|Mrs. Jacques Heat...|     F|35.0|     1|   53.1|Southampton|     yes|       1.0|         0.0|         1.0|
#         Allen|   Mr. William Henry|     M|35.0|     3|   8.05|Southampton|      no|       0.0|         0.0|         0.0|
#         Moran|           Mr. James|     M|30.0|     3| 8.4583| Queenstown|      no|       0.0|         2.0|         0.0|
#      McCarthy|       Mr. Timothy J|     M|54.0|     1|51.8625|Southampton|      no|       0.0|         0.0|         0.0|
#       Palsson|Master Gosta Leonard|     M| 2.0|     3| 21.075|Southampton|      no|       0.0|         0.0|         0.0|
#       Johnson|Mrs. Oscar W (Eli...|     F|27.0|     3|11.1333|Southampton|     yes|       1.0|         0.0|         1.0|
#        Nasser|Mrs. Nicholas (Ad...|     F|14.0|     2|30.0708|  Cherbourg|     yes|       1.0|         1.0|         1.0|
#     Sandstrom| Miss Marguerite Rut|     F| 4.0|     3|   16.7|Southampton|     yes|       1.0|         0.0|         1.0|
#       Bonnell|      Miss Elizabeth|     F|58.0|     1|  26.55|Southampton|     yes|       1.0|         0.0|         1.0|
#   Saundercock|   Mr. William Henry|     M|20.0|     3|   8.05|Southampton|      no|       0.0|         0.0|         0.0|
#     Andersson|    Mr. Anders Johan|     M|39.0|     3| 31.275|Southampton|      no|       0.0|         0.0|         0.0|
#       Vestrom|Miss Hulda Amanda...|     F|14.0|     3| 7.8542|Southampton|      no|       1.0|         0.0|         0.0|
#       Hewlett|Mrs. (Mary D King...|     F|55.0|     2|   16.0|Southampton|     yes|       1.0|         0.0|         1.0|
#          Rice|       Master Eugene|     M| 2.0|     3| 29.125| Queenstown|      no|       0.0|         2.0|         0.0|
#      Williams|  Mr. Charles Eugene|     M|30.0|     2|   13.0|Southampton|     yes|       0.0|         0.0|         1.0|
# Vander Planke|Mrs. Julius (Emel...|     F|31.0|     3|   18.0|Southampton|      no|       1.0|         0.0|         0.0|
#    Masselmani|         Mrs. Fatima|     F|30.0|     3|  7.225|  Cherbourg|     yes|       1.0|         1.0|         1.0|
# +-------------+--------------------+------+----+------+-------+-----------+--------+----------+------------+------------+
# only showing top 20 rows
#
# </div>

# %%
data = data.drop('gender','last','first','fare', 'embarked', 'survived')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Survived with respect to gender
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>Pclass</th><th>gender_new</th><th>embarked_new</th><th>survived_new</th></tr></thead><tbody><tr><td>22.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>38.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>26.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>35.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>35.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>54.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>27.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>14.0</td><td>2</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>4.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>58.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>20.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>39.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>14.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>55.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>30.0</td><td>2</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>31.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>35.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>34.0</td><td>2</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>15.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>28.0</td><td>1</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>8.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>38.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>19.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>40.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>30.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>66.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>28.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>42.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>21.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>14.0</td><td>3</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>40.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>27.0</td><td>2</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>3.0</td><td>2</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>19.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>7.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>21.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>49.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>29.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>65.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>30.0</td><td>1</td><td>0.0</td><td> ...

# %%
#Survive with respect to Pclass 
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>Pclass</th><th>gender_new</th><th>embarked_new</th><th>survived_new</th></tr></thead><tbody><tr><td>22.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>38.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>26.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>35.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>35.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>54.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>27.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>14.0</td><td>2</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>4.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>58.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>20.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>39.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>14.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>55.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>30.0</td><td>2</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>31.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>35.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>34.0</td><td>2</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>15.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>28.0</td><td>1</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>8.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>38.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>19.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>40.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>30.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>66.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>28.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>42.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>21.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>14.0</td><td>3</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>40.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>27.0</td><td>2</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>3.0</td><td>2</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>19.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>7.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>21.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>49.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>29.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>65.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>30.0</td><td>1</td><td>0.0</td><td> ...

# %%
# Survive with respect to age
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>Pclass</th><th>gender_new</th><th>embarked_new</th><th>survived_new</th></tr></thead><tbody><tr><td>22.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>38.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>26.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>35.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>35.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>54.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>27.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>14.0</td><td>2</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>4.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>58.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>20.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>39.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>14.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>55.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>30.0</td><td>2</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>31.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>35.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>34.0</td><td>2</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>15.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>28.0</td><td>1</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>8.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>38.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>19.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>40.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>30.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>66.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>28.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>42.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>21.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>14.0</td><td>3</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>40.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>27.0</td><td>2</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>3.0</td><td>2</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>19.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>7.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>21.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>49.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>29.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>65.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>30.0</td><td>1</td><td>0.0</td><td> ...

# %%
# Survive with respect to embarked 
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>Pclass</th><th>gender_new</th><th>embarked_new</th><th>survived_new</th></tr></thead><tbody><tr><td>22.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>38.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>26.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>35.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>35.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>54.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>27.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>14.0</td><td>2</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>4.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>58.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>20.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>39.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>14.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>55.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>30.0</td><td>2</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>31.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>35.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>34.0</td><td>2</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>15.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>28.0</td><td>1</td><td>0.0</td><td>0.0</td><td>1.0</td></tr><tr><td>8.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>38.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>19.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>40.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>30.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>66.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>28.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>42.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>1.0</td></tr><tr><td>21.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>14.0</td><td>3</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>40.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>27.0</td><td>2</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>3.0</td><td>2</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>19.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>2.0</td><td>0.0</td></tr><tr><td>30.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td></tr><tr><td>30.0</td><td>3</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td></tr><tr><td>7.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>21.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td></tr><tr><td>49.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td></tr><tr><td>29.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td></tr><tr><td>65.0</td><td>1</td><td>0.0</td><td>1.0</td><td>0.0</td></tr><tr><td>30.0</td><td>1</td><td>0.0</td><td> ...

# %%
assembler = VectorAssembler(inputCols=["age","Pclass","gender_new","embarked_new"],outputCol="features")
X_assembler = assembler.transform(data)
X_assembler.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+------+----------+------------+------------+------------------+
#  age|Pclass|gender_new|embarked_new|survived_new|          features|
# +----+------+----------+------------+------------+------------------+
# 22.0|     3|       0.0|         0.0|         0.0|[22.0,3.0,0.0,0.0]|
# 38.0|     1|       1.0|         1.0|         1.0|[38.0,1.0,1.0,1.0]|
# 26.0|     3|       1.0|         0.0|         1.0|[26.0,3.0,1.0,0.0]|
# 35.0|     1|       1.0|         0.0|         1.0|[35.0,1.0,1.0,0.0]|
# 35.0|     3|       0.0|         0.0|         0.0|[35.0,3.0,0.0,0.0]|
# 30.0|     3|       0.0|         2.0|         0.0|[30.0,3.0,0.0,2.0]|
# 54.0|     1|       0.0|         0.0|         0.0|[54.0,1.0,0.0,0.0]|
#  2.0|     3|       0.0|         0.0|         0.0| [2.0,3.0,0.0,0.0]|
# 27.0|     3|       1.0|         0.0|         1.0|[27.0,3.0,1.0,0.0]|
# 14.0|     2|       1.0|         1.0|         1.0|[14.0,2.0,1.0,1.0]|
#  4.0|     3|       1.0|         0.0|         1.0| [4.0,3.0,1.0,0.0]|
# 58.0|     1|       1.0|         0.0|         1.0|[58.0,1.0,1.0,0.0]|
# 20.0|     3|       0.0|         0.0|         0.0|[20.0,3.0,0.0,0.0]|
# 39.0|     3|       0.0|         0.0|         0.0|[39.0,3.0,0.0,0.0]|
# 14.0|     3|       1.0|         0.0|         0.0|[14.0,3.0,1.0,0.0]|
# 55.0|     2|       1.0|         0.0|         1.0|[55.0,2.0,1.0,0.0]|
#  2.0|     3|       0.0|         2.0|         0.0| [2.0,3.0,0.0,2.0]|
# 30.0|     2|       0.0|         0.0|         1.0|[30.0,2.0,0.0,0.0]|
# 31.0|     3|       1.0|         0.0|         0.0|[31.0,3.0,1.0,0.0]|
# 30.0|     3|       1.0|         1.0|         1.0|[30.0,3.0,1.0,1.0]|
# +----+------+----------+------------+------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
X_train, X_test = X_assembler.randomSplit([0.8, 0.2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml.evaluation import RegressionEvaluator
dt = DecisionTreeRegressor(labelCol="survived_new", featuresCol="features")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dt_model = dt.fit(X_train)
dt_predictions = dt_model.transform(X_test)
dt_predictions.select("prediction", "survived_new", "features").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+------------+------------------+
#          prediction|survived_new|          features|
# +-------------------+------------+------------------+
#                 1.0|         1.0| [1.0,2.0,0.0,1.0]|
#  0.2857142857142857|         1.0| [1.0,3.0,1.0,0.0]|
#  0.9565217391304348|         0.0| [2.0,1.0,1.0,0.0]|
#                 1.0|         1.0| [2.0,2.0,1.0,0.0]|
#                 0.5|         0.0| [2.0,3.0,0.0,0.0]|
#  0.2857142857142857|         0.0| [2.0,3.0,1.0,0.0]|
#  0.2857142857142857|         1.0| [2.0,3.0,1.0,0.0]|
#                 0.5|         1.0| [3.0,3.0,0.0,0.0]|
#  0.2857142857142857|         1.0| [4.0,3.0,1.0,0.0]|
#  0.2857142857142857|         1.0| [4.0,3.0,1.0,0.0]|
# 0.38461538461538464|         0.0| [9.0,3.0,0.0,0.0]|
# 0.38461538461538464|         0.0|[10.0,3.0,0.0,0.0]|
# 0.38461538461538464|         0.0|[11.0,3.0,0.0,0.0]|
#  0.7272727272727273|         1.0|[15.0,3.0,1.0,2.0]|
#  0.9565217391304348|         1.0|[16.0,1.0,1.0,1.0]|
#   0.102880658436214|         0.0|[16.0,3.0,0.0,0.0]|
#  0.5714285714285714|         0.0|[16.0,3.0,1.0,0.0]|
#  0.9565217391304348|         1.0|[17.0,1.0,1.0,0.0]|
#   0.102880658436214|         0.0|[17.0,3.0,0.0,0.0]|
#   0.102880658436214|         0.0|[17.0,3.0,0.0,0.0]|
# +-------------------+------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
evaluator = RegressionEvaluator(
    labelCol="survived_new", predictionCol="prediction", metricName="rmse")
rmse = evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root Mean Squared Error (RMSE) on test data = 0.391572
# </div>

# %%
dt_predictions.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: 165</div>

# %%
display(dt_predictions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>Pclass</th><th>gender_new</th><th>embarked_new</th><th>survived_new</th><th>features</th><th>prediction</th></tr></thead><tbody><tr><td>1.0</td><td>2</td><td>0.0</td><td>1.0</td><td>1.0</td><td>List(1, 4, List(), List(1.0, 2.0, 0.0, 1.0))</td><td>1.0</td></tr><tr><td>1.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td><td>List(1, 4, List(), List(1.0, 3.0, 1.0, 0.0))</td><td>0.2857142857142857</td></tr><tr><td>2.0</td><td>1</td><td>1.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(2.0, 1.0, 1.0, 0.0))</td><td>0.9565217391304348</td></tr><tr><td>2.0</td><td>2</td><td>1.0</td><td>0.0</td><td>1.0</td><td>List(1, 4, List(), List(2.0, 2.0, 1.0, 0.0))</td><td>1.0</td></tr><tr><td>2.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(2.0, 3.0, 0.0, 0.0))</td><td>0.5</td></tr><tr><td>2.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(2.0, 3.0, 1.0, 0.0))</td><td>0.2857142857142857</td></tr><tr><td>2.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td><td>List(1, 4, List(), List(2.0, 3.0, 1.0, 0.0))</td><td>0.2857142857142857</td></tr><tr><td>3.0</td><td>3</td><td>0.0</td><td>0.0</td><td>1.0</td><td>List(1, 4, List(), List(3.0, 3.0, 0.0, 0.0))</td><td>0.5</td></tr><tr><td>4.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td><td>List(1, 4, List(), List(4.0, 3.0, 1.0, 0.0))</td><td>0.2857142857142857</td></tr><tr><td>4.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td><td>List(1, 4, List(), List(4.0, 3.0, 1.0, 0.0))</td><td>0.2857142857142857</td></tr><tr><td>9.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(9.0, 3.0, 0.0, 0.0))</td><td>0.38461538461538464</td></tr><tr><td>10.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(10.0, 3.0, 0.0, 0.0))</td><td>0.38461538461538464</td></tr><tr><td>11.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(11.0, 3.0, 0.0, 0.0))</td><td>0.38461538461538464</td></tr><tr><td>15.0</td><td>3</td><td>1.0</td><td>2.0</td><td>1.0</td><td>List(1, 4, List(), List(15.0, 3.0, 1.0, 2.0))</td><td>0.7272727272727273</td></tr><tr><td>16.0</td><td>1</td><td>1.0</td><td>1.0</td><td>1.0</td><td>List(1, 4, List(), List(16.0, 1.0, 1.0, 1.0))</td><td>0.9565217391304348</td></tr><tr><td>16.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(16.0, 3.0, 0.0, 0.0))</td><td>0.102880658436214</td></tr><tr><td>16.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(16.0, 3.0, 1.0, 0.0))</td><td>0.5714285714285714</td></tr><tr><td>17.0</td><td>1</td><td>1.0</td><td>0.0</td><td>1.0</td><td>List(1, 4, List(), List(17.0, 1.0, 1.0, 0.0))</td><td>0.9565217391304348</td></tr><tr><td>17.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(17.0, 3.0, 0.0, 0.0))</td><td>0.102880658436214</td></tr><tr><td>17.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(17.0, 3.0, 0.0, 0.0))</td><td>0.102880658436214</td></tr><tr><td>18.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(18.0, 2.0, 0.0, 0.0))</td><td>0.102880658436214</td></tr><tr><td>18.0</td><td>2</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(18.0, 2.0, 0.0, 0.0))</td><td>0.102880658436214</td></tr><tr><td>18.0</td><td>3</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(18.0, 3.0, 0.0, 0.0))</td><td>0.102880658436214</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(18.0, 3.0, 1.0, 0.0))</td><td>0.5714285714285714</td></tr><tr><td>18.0</td><td>3</td><td>1.0</td><td>0.0</td><td>1.0</td><td>List(1, 4, List(), List(18.0, 3.0, 1.0, 0.0))</td><td>0.5714285714285714</td></tr><tr><td>19.0</td><td>1</td><td>0.0</td><td>0.0</td><td>0.0</td><td>List(1, 4, List(), List(19.0, 1.0, ...
